# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.2
# attrs                   26.1.0
# beautifulsoup4          4.15.0
# certifi                 2026.6.17
# cffi                    2.1.0
# colorama                0.4.6
# comm                    0.2.3
# debugpy                 1.8.21
# decorator               5.3.1
# executing               2.2.1
# h11                     0.16.0
# idna                    3.18
# ipykernel               7.3.0
# ipython                 9.15.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.20.0
# jupyter_client          8.9.1
# jupyter_core            5.9.1
# lxml                    6.1.1
# matplotlib-inline       0.2.2
# nest-asyncio2           1.7.2
# numpy                   2.5.1
# outcome                 1.3.0.post0
# packaging               26.2
# pandas                  3.0.3
# parso                   0.8.7
# pip                     24.3.1
# platformdirs            4.10.1
# ...

# %%
with open("smart_phone.html","r") as f:
    content = f.read()
    soup=BeautifulSoup(content,"lxml")

# %%
print(soup.prettify)

# %%
def get_text(lst, index):
    try:
        return lst[index].text
    except IndexError:
        return None



sim.append(get_text(x, 0))
processor.append(get_text(x, 1))
ram.append(get_text(x, 2))
battery.append(get_text(x, 3))
display.append(get_text(x, 4))
camera.append(get_text(x, 5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 9
#       5         return None
#       6
#       7
#       8
# ----> 9 sim.append(get_text(x, 0))
#      10 processor.append(get_text(x, 1))
#      11 ram.append(get_text(x, 2))
#      12 battery.append(get_text(x, 3))
#
# NameError: name 'sim' is not defined
